# %%
# Importing the libraries
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')
import pandas as pd
from sklearn.preprocessing import MinMaxScaler, LabelEncoder
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense, SimpleRNN, Dropout, Bidirectional
from keras.optimizers import SGD, Adam, RMSprop, Adadelta, Adagrad
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
import math
from sklearn.metrics import mean_squared_error

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
dataset = pd.read_csv('/content/drive/MyDrive/Marek/Uni/Seminar_25/time-series_data.csv')

# %%
dataset.dropna(inplace=True)

# %%
#Spalte 'week' in datetime konvertieren
dataset['week'] = pd.to_datetime(dataset['week'], format='%d/%m/%y')

# %%
# Vorbereitung der Variablen

numeric_features = ['units_sold', 'total_price', 'base_price']
categorical_features = ['store_id', 'sku_id']

# Label Encoding für kategoriale Features
le_store = LabelEncoder()
le_sku = LabelEncoder()

dataset['store_id_encoded'] = le_store.fit_transform(dataset['store_id'])
dataset['sku_id_encoded'] = le_sku.fit_transform(dataset['sku_id'])

# Neue Features für die Sequenzierung, inklusive der binären Variablen
features = numeric_features + ['is_featured_sku', 'is_display_sku', 'store_id_encoded', 'sku_id_encoded']

# %%
# Erstellung Trainingsset

# Schritt 1: Eindeutige 'week'-Werte extrahieren
unique_weeks = dataset.index.unique()
n_weeks = len(unique_weeks)

weeks_train = int(0.75 * n_weeks)

# Schritt 2: Definiere die Grenzen für die Sets
train_weeks = unique_weeks[:weeks_train]
rest_weeks = unique_weeks[weeks_train:]

# Schritt 3: Daten in die jeweiligen Sets aufteilen
train_set = dataset[dataset.index.isin(train_weeks)]
print("Trainingsset:")
print(f"Anzahl der Reihen: {train_set.shape[0]}, mögliche Länge der Sequenzen: {train_set.index.nunique()}")

rest_set = dataset[dataset.index.isin(rest_weeks)]
print("Rest-Set:")
print(f"Anzahl der Reihen: {rest_set.shape[0]}, mögliche Länge der Sequenzen: {rest_set.index.nunique()}")
# Out:
# Trainingsset:
# Anzahl der Reihen: 112611, mögliche Länge der Sequenzen: 112611
# Rest-Set:
# Anzahl der Reihen: 37538, mögliche Länge der Sequenzen: 37538

# %%
# Erstellung Validierungs- und Testset

# Schritt 1: Gruppierung nach 'store_id' und 'sku_id'
rest_grouped = list(rest_set.groupby(['store_id', 'sku_id']))

# Schritt 2: Shuffle der Gruppen, um eine zufällige Verteilung zu gewährleisten
np.random.seed(42)  # für Reproduzierbarkeit
np.random.shuffle(rest_grouped)

# Schritt 3: Aufteilung der Gruppen in Sets
n_groups = len(rest_grouped)
split = int(0.5 * n_groups)

val_groups = rest_grouped[:split]
test_groups = rest_grouped[split:]

# Schritt 4: Neue DataFrames für die Sets erstellen
val_set = pd.concat([group for _, group in val_groups])
test_set = pd.concat([group for _, group in test_groups])

# Überprüfung der Größen
print("Validierungsset:")
print(f"Anzahl der Reihen: {val_set.shape[0]}, Anzahl der Gruppen: {len(val_groups)}, Länge der Reihen: {val_set.index.nunique()}")
print("Test-Set:")
print(f"Anzahl der Reihen: {test_set.shape[0]}, Anzahl der Gruppen: {len(test_groups)}, Länge der Reihen: {test_set.index.nunique()}")
# Out:
# Validierungsset:
# Anzahl der Reihen: 18739, Anzahl der Gruppen: 577, Länge der Reihen: 18739
# Test-Set:
# Anzahl der Reihen: 18799, Anzahl der Gruppen: 578, Länge der Reihen: 18799

# %%
# Index zurücksetzen

# Schritt 1: Den Index wieder auf den datetime 'week' setzen (falls nicht mehr so)
train_set = train_set.set_index('week')
val_set = val_set.set_index('week')
test_set = test_set.set_index('week')

# Schritt 2: Nach 'week' sortieren
train_set = train_set.sort_index()
val_set = val_set.sort_index()
test_set = test_set.sort_index()

# %%
print("Trainingsset:")
print(f"Anzahl der Reihen: {train_set.shape[0]}, mögliche Länge der Sequenzen: {train_set.index.nunique()}")
print()
print("Validierungsset:")
print(f"Anzahl der Reihen: {val_set.shape[0]}, Anzahl der Gruppen: {len(val_groups)}, Länge der Reihen: {val_set.index.nunique()}")
print()
print("Test-Set:")
print(f"Anzahl der Reihen: {test_set.shape[0]}, Anzahl der Gruppen: {len(test_groups)}, Länge der Reihen: {test_set.index.nunique()}")
# Out:
# Trainingsset:
# Anzahl der Reihen: 112611, mögliche Länge der Sequenzen: 98
#
# Validierungsset:
# Anzahl der Reihen: 18739, Anzahl der Gruppen: 577, Länge der Reihen: 33
#
# Test-Set:
# Anzahl der Reihen: 18799, Anzahl der Gruppen: 578, Länge der Reihen: 33

# %%
print("Trainingsset:")
train_set.info()
train_set.head()
# Out:
# Trainingsset:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 112611 entries, 2011-01-17 to 2012-11-27
# Data columns (total 10 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   record_ID         112611 non-null  int64
#  1   store_id          112611 non-null  int64
#  2   sku_id            112611 non-null  int64
#  3   total_price       112611 non-null  float64
#  4   base_price        112611 non-null  float64
#  5   is_featured_sku   112611 non-null  int64
#  6   is_display_sku    112611 non-null  int64
#  7   units_sold        112611 non-null  int64
#  8   store_id_encoded  112611 non-null  int64
#  9   sku_id_encoded    112611 non-null  int64
# dtypes: float64(2), int64(8)
# memory usage: 13.5 MB
#             record_ID  store_id  sku_id  total_price  base_price  \
# week
# 2011-01-17          1      8091  216418      99.0375    111.8625
# 2011-01-17          2      8091  216419      99.0375     99.0375
# 2011-01-17          3      8091  216425     133.9500    133.9500
# 2011-01-17          4      8091  216233     133.9500    133.9500
# 2011-01-17          5      8091  217390     141.0750    141.0750
#
#             is_featured_sku  is_display_sku  units_sold  store_id_encoded  \
# week
# 2011-01-17                0               0          20                 3
# 2011-01-17                0               0          28                 3
# 2011-01-17                0               0          19                 3
# 2011-01-17                0               0          44                 3
# 2011-01-17                0               0          52                 3
#
#             sku_id_encoded
# week
# 2011-01-17               1
# 2011-01-17               2
# 2011-01-17               3
# 2011-01-17               0
# 2011-01-17               5

# %%
print("Validierungsset:")
val_set.info()
val_set.head()
# Out:
# Validierungsset:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 18739 entries, 2012-11-27 to 2013-07-09
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   record_ID         18739 non-null  int64
#  1   store_id          18739 non-null  int64
#  2   sku_id            18739 non-null  int64
#  3   total_price       18739 non-null  float64
#  4   base_price        18739 non-null  float64
#  5   is_featured_sku   18739 non-null  int64
#  6   is_display_sku    18739 non-null  int64
#  7   units_sold        18739 non-null  int64
#  8   store_id_encoded  18739 non-null  int64
#  9   sku_id_encoded    18739 non-null  int64
# dtypes: float64(2), int64(8)
# memory usage: 2.1 MB
#             record_ID  store_id  sku_id  total_price  base_price  \
# week
# 2012-11-27     160008      9823  673209     355.5375    355.5375
# 2012-11-27     159508      9439  219009     190.2375    190.2375
# 2012-11-27     159667      9498  216419      86.9250     86.9250
# 2012-11-27     160007      9823  547934     177.4125    177.4125
# 2012-11-27     160288      9984  245338     391.8750    469.5375
#
#             is_featured_sku  is_display_sku  units_sold  store_id_encoded  \
# week
# 2012-11-27                0               0          49                63
# 2012-11-27                0               0          60                41
# 2012-11-27                0               0          34                47
# 2012-11-27                0               0          23                63
# 2012-11-27                1               0          23                75
#
#             sku_id_encoded
# week
# 2012-11-27              26
# 2012-11-27               7
# 2012-11-27               2
# 2012-11-27              24
# 2012-11-27              14

# %%
print("Testset:")
test_set.info()
test_set.head()
# Out:
# Testset:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 18799 entries, 2012-11-27 to 2013-07-09
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   record_ID         18799 non-null  int64
#  1   store_id          18799 non-null  int64
#  2   sku_id            18799 non-null  int64
#  3   total_price       18799 non-null  float64
#  4   base_price        18799 non-null  float64
#  5   is_featured_sku   18799 non-null  int64
#  6   is_display_sku    18799 non-null  int64
#  7   units_sold        18799 non-null  int64
#  8   store_id_encoded  18799 non-null  int64
#  9   sku_id_encoded    18799 non-null  int64
# dtypes: float64(2), int64(8)
# memory usage: 2.1 MB
#             record_ID  store_id  sku_id  total_price  base_price  \
# week
# 2012-11-27     160238      9954  245338     391.8750    469.5375
# 2012-11-27     160002      9823  223153     236.5500    236.5500
# 2012-11-27     160039      9809  219029     327.0375    327.0375
# 2012-11-27     159614      9479  222765     175.9875    227.2875
# 2012-11-27     159616      9479  223153     235.8375    235.8375
#
#             is_featured_sku  is_display_sku  units_sold  store_id_encoded  \
# week
# 2012-11-27                1               0          27                73
# 2012-11-27                0               0          40                63
# 2012-11-27                0               0          36                61
# 2012-11-27                0               0          50                44
# 2012-11-27                0               0          26                44
#
#             sku_id_encoded
# week
# 2012-11-27              14
# 2012-11-27              12
# 2012-11-27               8
# 2012-11-27              11
# 2012-11-27              12

# %%
# Skalierer nur für die numerischen Features (ohne binäre)
scalers = {feature: MinMaxScaler() for feature in numeric_features}

for feature in numeric_features:
  scalers[feature].fit(train_set[feature].values.reshape(-1, 1))

# %%
# Funktion zur Erstellung von Sequenzen
def create_sequences(dataset, features, numeric_features, scalers, timesteps):
    X_all = []
    y_all = []

    grouped = dataset.groupby(['store_id', 'sku_id'])

    for (store_id, sku_id), group in grouped:
        group = group.sort_index()

        # Daten extrahieren
        data = group[features].values

        # Skalieren der numerischen Features
        for feature in numeric_features:
            index = features.index(feature)
            data[:, index] = scalers[feature].transform(data[:, index].reshape(-1, 1)).flatten()

        # Kategoriale Features bleiben als Integer

        for i in range(timesteps, len(data)):
            X_seq = data[i - timesteps:i]
            X_all.append(X_seq)
            y_all.append(data[i, 0])  # units_sold ist der erste Wert in features

    X_array = np.array(X_all)
    y_array = np.array(y_all)
    return X_array, y_array

# %%
# Liste der Fenstergrößen
window_sizes = [30]

# Dictionary, um die erzeugten Datensätze zu speichern
train_sets = {}
val_sets = {}

for window in window_sizes:
    X_train, y_train = create_sequences(train_set, features, numeric_features, scalers, window)
    train_sets[window] = {'X': X_train, 'y': y_train}

    X_val, y_val = create_sequences(val_set, features, numeric_features, scalers, window)
    val_sets[window] = {'X': X_val, 'y': y_val}

    print(f"Fenstergröße {window}:")
    print(f"Trainings-Sequenzen: {X_train.shape}, Validierungs-Sequenzen: {X_val.shape}.")
# Out:
# Fenstergröße 30:
# Trainings-Sequenzen: (77961, 30, 7), Validierungs-Sequenzen: (1429, 30, 7).

# %%
X_tr = train_sets[30]['X']
y_tr = train_sets[30]['y']
X_v = val_sets[30]['X']
y_v = val_sets[30]['y']

# %%
# Hyperparameter-Optionen
layer_options = [1, 2, 3]
units_options = [32, 64]

# Ergebnisse speichern
results = {}

for n_layers in layer_options:
    for units in units_options:
        print(f"\nTraining: {n_layers} Schichten, {units} Units (SimpleRNN)")

        model = Sequential()

        # Erste Schicht
        model.add(SimpleRNN(units=units, input_shape=(X_tr.shape[1], X_tr.shape[2]), return_sequences=(n_layers > 1)))

        # Zusätzliche Schichten bei Bedarf
        for layer_idx in range(1, n_layers):
            return_seq = (layer_idx < n_layers - 1)
            model.add(SimpleRNN(units=units, return_sequences=return_seq))

        # Endfolger
        model.add(Dense(1, activation='linear'))

        # Kompilieren mit SGD, Lernrate 0,01
        model.compile(optimizer=SGD(learning_rate=0.01), loss='mean_squared_error')

        # Training
        history = model.fit(X_tr, y_tr, epochs=10, batch_size=64, validation_data=(X_v, y_v))

        train_losses = history.history['loss']
        val_losses = history.history['val_loss']

        # Resultate speichern
        key = (n_layers, units)
        results[key] = {'train_loss': train_losses, 'val_loss': val_losses}

        # Ausgabe
        print(f"Durchschnittlicher Validierungsverlust: {np.mean(val_losses):.6f}")
        print(f"Bester Validierungsverlust: {np.min(val_losses):.6f}")
# Out:
# Training: 1 Schichten, 32 Units (SimpleRNN)
# Epoch 1/10
# 1219/1219 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - loss: 0.0322 - val_loss: 0.0015
# Epoch 2/10
# 1219/1219 ━━━━━━━━━━━━━━━━━━━━ 9s 7ms/step - loss: 0.0012 - val_loss: 0.0012
# Epoch 3/10
# 1219/1219 ━━━━━━━━━━━━━━━━━━━━ 11s 8ms/step - loss: 9.6978e-04 - val_loss: 9.8451e-04
# Epoch 4/10
# 1219/1219 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - loss: 8.1377e-04 - val_loss: 8.7959e-04
# Epoch 5/10
# 1219/1219 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - loss: 7.3879e-04 - val_loss: 8.2472e-04
# Epoch 6/10
# 1219/1219 ━━━━━━━━━━━━━━━━━━━━ 11s 8ms/step - loss: 6.8800e-04 - val_loss: 7.7091e-04
# Epoch 7/10
# 1219/1219 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - loss: 6.6313e-04 - val_loss: 7.7242e-04
# Epoch 8/10
# 1219/1219 ━━━━━━━━━━━━━━━━━━━━ 9s 7ms/step - loss: 6.1262e-04 - val_loss: 7.3288e-04
# Epoch 9/10
# 1219/1219 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - loss: 6.1911e-04 - val_loss: 6.9849e-04
# Epoch 10/10
# 1219/1219 ━━━━━━━━━━━━━━━━━━━━ 12s 8ms/step - loss: 5.6606e-04 - val_loss: 6.8018e-04
# Durchschnittlicher Validierungsverlust: 0.000902
# Bester Validierungsverlust: 0.000680
#
# Training: 1 Schichten, 64 Units (SimpleRNN)
# Epoch 1/10
# 1219/1219 ━━━━━━━━━━━━━━━━━━━━ 12s 9ms/step - loss: 0.0568 - val_loss: 0.0013
# Epoch 2/10
# 1219/1219 ━━━━━━━━━━━━━━━━━━━━ 19s 9ms/step - loss: 8.0121e-04 - val_loss: 0.0013
# Epoch 3/10
# 1219/1219 ━━━━━━━━━━━━━━━━━━━━ 21s 9ms/step - loss: 6.5431e-04 - val_loss: 0.0014
# Epoch 4/10
# 1219/1219 ━━━━━━━━━━━━━━━━━━━━ 11s 9ms/step - loss: 6.1254e-04 - val_loss: 7.4902e-04
# Epoch 5/10
# 1219/1219 ━━━━━━━━━━━━━━━━━━━━ 20s 9ms/step - loss: 5.4412e-04 - val_loss: 6.7925e-04
# Epoch 6/10
# 1219/1219 ━━━━━━━━━━━━━━━━━━━━ 21s 9ms/step - loss: 5.3961e-04 - val_loss: 6.8368e-04
# Epoch 7/10
# 1219/1219 ━━━━━━━━━━━━━━━━━━━━ 11s 9ms/step - loss: 5.0700e-04 - val_loss: 8.5758e-04
# Epoch 8/10
# 1219/1219 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - loss: 5.0670e-04 - val_loss: 6.4908e-04
# Epoch 9/10
# 1219/1219 ━━━━━━━━━━━━━━━━━━━━ 11s 9ms/step - loss:
10
# 1219/1219 ━━━━━━━━━━━━━━━━━━━━ 40s 28ms/step - loss: 6.6448e-04 - val_loss: 8.0440e-04
# Epoch 3/10
# 1219/1219 ━━━━━━━━━━━━━━━━━━━━ 41s 28ms/step - loss: 5.5675e-04 - val_loss: 6.0805e-04
# Epoch 4/10
# 1219/1219 ━━━━━━━━━━━━━━━━━━━━ 36s 30ms/step - loss: 5.1831e-04 - val_loss: 5.8928e-04
# Epoch 5/10
# 1219/1219 ━━━━━━━━━━━━━━━━━━━━ 35s 28ms/step - loss: 4.8266e-04 - val_loss: 8.7245e-04
# Epoch 6/10
# 1219/1219 ━━━━━━━━━━━━━━━━━━━━ 37s 30ms/step - loss: 4.6679e-04 - val_loss: 5.4928e-04
# Epoch 7/10
# 1219/1219 ━━━━━━━━━━━━━━━━━━━━ 40s 29ms/step - loss: 4.5987e-04 - val_loss: 5.5149e-04
# Epoch 8/10
# 1219/1219 ━━━━━━━━━━━━━━━━━━━━ 39s 28ms/step - loss: 4.3962e-04 - val_loss: 7.1356e-04
# Epoch 9/10
# 1219/1219 ━━━━━━━━━━━━━━━━━━━━ 37s 30ms/step - loss: 4.3097e-04 - val_loss: 5.1737e-04
# Epoch 10/10
# 1219/1219 ━━━━━━━━━━━━━━━━━━━━ 34s 28ms/step - loss: 4.4695e-04 - val_loss: 6.2089e-04
# Durchschnittlicher Validierungsverlust: 0.000655
# Bester Validierungsverlust: 0.000517

# %%
# Liste der Optimizer und Lernraten
optimizers = {
    'Adam': Adam,
    'RMSprop': RMSprop,
    'Adadelta': Adadelta,
    'Adagrad': Adagrad
}

learning_rates = [0.001, 0.005, 0.01, 0.05, 0.1]

# Ergebnisse speichern
results = []

for opt_name, opt_func in optimizers.items():
    for lr in learning_rates:
        print(f"Testen mit Optimizer: {opt_name}, Lernrate: {lr}")

        # Modell erstellen
        model = Sequential()

        #Erste Schicht
        model.add(SimpleRNN(units=64,
                       input_shape=(X_tr.shape[1], X_tr.shape[2]),
                       return_sequences=True))

        #Zweite Schicht
        model.add(SimpleRNN(units=64, return_sequences=True))

        #Dritte Schicht
        model.add(SimpleRNN(units=64))

        model.add(Dense(1, activation='linear'))

        # Optimizer Instanziieren
        optimizer = opt_func(learning_rate=lr)

        # Modell kompilieren
        model.compile(optimizer=optimizer,
                      loss='mean_squared_error')

        # Training durchführen
        history = model.fit(X_tr, y_tr, epochs=10, batch_size=64,
                            validation_data=(X_v, y_v))

        # Validation Loss speichern
        val_loss = np.min(history.history['val_loss'])
        print(f"Validierungsverlust: {val_loss:.6f}")
        results.append({
            'optimizer': opt_name,
            'learning_rate': lr,
            'val_loss': val_loss
        })

# Ergebnisse anzeigen
for res in results:
    print(f"Optimizer: {res['optimizer']}, Lernrate: {res['learning_rate']}, "
          f"Bester Validierungsverlust: {res['val_loss']:.6f}")
# Out:
# Testen mit Optimizer: Adam, Lernrate: 0.001
# Epoch 1/10
# 1219/1219 ━━━━━━━━━━━━━━━━━━━━ 40s 30ms/step - loss: 0.0406 - val_loss: 7.2399e-04
# Epoch 2/10
# 1219/1219 ━━━━━━━━━━━━━━━━━━━━ 39s 32ms/step - loss: 4.9048e-04 - val_loss: 6.9927e-04
# Epoch 3/10
# 1219/1219 ━━━━━━━━━━━━━━━━━━━━ 39s 30ms/step - loss: 4.6074e-04 - val_loss: 6.3873e-04
# Epoch 4/10
# 1219/1219 ━━━━━━━━━━━━━━━━━━━━ 41s 30ms/step - loss: 4.7439e-04 - val_loss: 5.9878e-04
# Epoch 5/10
# 1219/1219 ━━━━━━━━━━━━━━━━━━━━ 35s 28ms/step - loss: 4.7931e-04 - val_loss: 5.0689e-04
# Epoch 6/10
# 1219/1219 ━━━━━━━━━━━━━━━━━━━━ 36s 30ms/step - loss: 4.3191e-04 - val_loss: 4.8731e-04
# Epoch 7/10
# 1219/1219 ━━━━━━━━━━━━━━━━━━━━ 40s 29ms/step - loss: 3.7757e-04 - val_loss: 3.6823e-04
# Epoch 8/10
# 1219/1219 ━━━━━━━━━━━━━━━━━━━━ 40s 28ms/step - loss: 3.3637e-04 - val_loss: 4.3887e-04
# Epoch 9/10
# 1219/1219 ━━━━━━━━━━━━━━━━━━━━
10
# 1219/1219 ━━━━━━━━━━━━━━━━━━━━ 41s 30ms/step - loss: 3.7171e-04 - val_loss: 4.7058e-04
# Epoch 8/10
# 1219/1219 ━━━━━━━━━━━━━━━━━━━━ 41s 30ms/step - loss: 3.7104e-04 - val_loss: 4.5351e-04
# Epoch 9/10
# 1219/1219 ━━━━━━━━━━━━━━━━━━━━ 41s 30ms/step - loss: 3.6847e-04 - val_loss: 4.7462e-04
# Epoch 10/10
# 1219/1219 ━━━━━━━━━━━━━━━━━━━━ 39s 32ms/step - loss: 3.7381e-04 - val_loss: 4.5324e-04
# Validierungsverlust: 0.000453
# Testen mit Optimizer: Adagrad, Lernrate: 0.1
# Epoch 1/10
# 1219/1219 ━━━━━━━━━━━━━━━━━━━━ 42s 32ms/step - loss: 0.2370 - val_loss: 0.0010
# Epoch 2/10
# 1219/1219 ━━━━━━━━━━━━━━━━━━━━ 39s 31ms/step - loss: 3.8200e-04 - val_loss: 4.9904e-04
# Epoch 3/10
# 1219/1219 ━━━━━━━━━━━━━━━━━━━━ 41s 31ms/step - loss: 3.8409e-04 - val_loss: 5.3057e-04
# Epoch 4/10
# 1219/1219 ━━━━━━━━━━━━━━━━━━━━ 40s 30ms/step - loss: 3.6938e-04 - val_loss: 4.9119e-04
# Epoch 5/10
# 1219/1219 ━━━━━━━━━━━━━━━━━━━━ 41s 30ms/step - loss: 3.6417e-04 - val_loss: 5.9449e-04
# Epoch 6/10
# 1219/1219 ━━━━━━━━━━━━━━━━━━━━ 38s 31ms/step - loss: 3.6059e-04 - val_loss: 4.8469e-04
# Epoch 7/10
# 1219/1219 ━━━━━━━━━━━━━━━━━━━━ 42s 32ms/step - loss: 3.7561e-04 - val_loss: 5.5681e-04
# Epoch 8/10
# 1219/1219 ━━━━━━━━━━━━━━━━━━━━ 40s 31ms/step - loss: 4.0478e-04 - val_loss: 4.9278e-04
# Epoch 9/10
# 1219/1219 ━━━━━━━━━━━━━━━━━━━━ 40s 31ms/step - loss: 3.6911e-04 - val_loss: 4.9090e-04
# Epoch 10/10
# 1219/1219 ━━━━━━━━━━━━━━━━━━━━ 39s 32ms/step - loss: 3.8856e-04 - val_loss: 5.1981e-04
# Validierungsverlust: 0.000485
# Optimizer: Adam, Lernrate: 0.001, Bester Validierungsverlust: 0.000312
# Optimizer: Adam, Lernrate: 0.005, Bester Validierungsverlust: 0.000318
# Optimizer: Adam, Lernrate: 0.01, Bester Validierungsverlust: 0.000481
# Optimizer: Adam, Lernrate: 0.05, Bester Validierungsverlust: 0.000497
# Optimizer: Adam, Lernrate: 0.1, Bester Validierungsverlust: 0.000879
# Optimizer: RMSprop, Lernrate: 0.001, Bester Validierungsverlust: 0.000460
# Optimizer: RMSprop, Lernrate: 0.005, Bester Validierungsverlust: 0.007858
# Optimizer: RMSprop, Lernrate: 0.01, Bester Validierungsverlust: 0.059241
# Optimizer: RMSprop, Lernrate: 0.05, Bester Validierungsverlust: 2.567917
# Optimizer: RMSprop, Lernrate: 0.1, Bester Validierungsverlust: 10.191051
# Optimizer: Adadelta, Lernrate: 0.001, Bester Validierungsverlust: 0.001618
# Optimizer: Adadelta, Lernrate: 0.005, Bester Validierungsverlust: 0.001195
# Optimizer: Adadelta, Lernrate: 0.01, Bester Validierungsverlust: 0.000576
# Optimizer: Adadelta, Lernrate: 0.05, Bester Validierungsverlust: 0.000532
# Optimizer: Adadelta, Lernrate: 0.1, Bester Validierungsverlust: 0.000514
# Optimizer: Adagrad, Lernrate: 0.001, Bester Validierungsverlust: 0.000844
# Optimizer: Adagrad, Lernrate: 0.005, Bester Validierungsverlust: 0.000512
# Optimizer: Adagrad, Lernrate: 0.01, Bester Validierungsverlust: 0.000471
# Optimizer: Adagrad, Lernrate: 0.05, Bester Validierungsverlust: 0.000453
# Optimizer: Adagrad, Lernrate: 0.1, Bester Validierungsverlust: 0.000485

# %%
# Modell erstellen
model_RNN_01 = Sequential()
model_RNN_01.add(SimpleRNN(units=64,
                input_shape=(X_tr.shape[1], X_tr.shape[2]),
                return_sequences=True))
model_RNN_01.add(SimpleRNN(units=64, return_sequences=True))
model_RNN_01.add(SimpleRNN(units=64))
model_RNN_01.add(Dense(1, activation='linear'))

# Modell kompilieren
model_RNN_01.compile(optimizer=Adam(learning_rate=0.01),
              loss='mean_squared_error')

# EarlyStopping Callback definieren
early_stop = EarlyStopping(monitor='val_loss', patience=7, restore_best_weights=True)

# Lernratenabbaufaktor
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=3, min_lr=1e-8)

# Training durchführen
history = model_RNN_01.fit(X_tr, y_tr, epochs=50, batch_size=64,
                    validation_data=(X_v, y_v), callbacks=[early_stop, reduce_lr])

# Validation Loss speichern
val_loss = np.min(history.history['val_loss'])
print(f"Validierungsverlust: {val_loss:.6f}")
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/50
# 1219/1219 ━━━━━━━━━━━━━━━━━━━━ 43s 32ms/step - loss: 0.0824 - val_loss: 5.8486e-04 - learning_rate: 0.0100
# Epoch 2/50
# 1219/1219 ━━━━━━━━━━━━━━━━━━━━ 35s 29ms/step - loss: 5.2136e-04 - val_loss: 4.5063e-04 - learning_rate: 0.0100
# Epoch 3/50
# 1219/1219 ━━━━━━━━━━━━━━━━━━━━ 40s 28ms/step - loss: 6.4522e-04 - val_loss: 7.0131e-04 - learning_rate: 0.0100
# Epoch 4/50
# 1219/1219 ━━━━━━━━━━━━━━━━━━━━ 41s 28ms/step - loss: 7.0777e-04 - val_loss: 0.0017 - learning_rate: 0.0100
# Epoch 5/50
# 1219/1219 ━━━━━━━━━━━━━━━━━━━━ 41s 28ms/step - loss: 7.2377e-04 - val_loss: 5.2621e-04 - learning_rate: 0.0100
# Epoch 6/50
# 1219/1219 ━━━━━━━━━━━━━━━━━━━━ 36s 29ms/step - loss: 3.2964e-04 - val_loss: 4.3427e-04 - learning_rate: 1.0000e-03
# Epoch 7/50
# 1219/1219 ━━━━━━━━━━━━━━━━━━━━ 34s 28ms/step - loss: 3.0452e-04 - val_loss: 3.7185e-04 - learning_rate: 1.0000e-03
# Epoch 8/50
# 1219/1219 ━━━━━━━━━━━━━━━━━━━━ 41s 28ms/step - loss: 3.1190e-04 - val_loss: 3.5169e-04 - learning_rate: 1.0000e-03
# Epoch 9/50
# 1219/1219 ━━━━━━━━━━━━━━━━━━━━ 36s 29ms/step - loss: 2.3503e-04 - val_loss: 3.1496e-04 - learning_rate: 1.0000e-04
# Epoch 10/50
# 1219/1219 ━━━━━━━━━━━━━━━━━━━━ 34s 28ms/step - loss: 2.4171e-04 - val_loss: 3.1275e-04 - learning_rate: 1.0000e-04
# Epoch 11/50
# 1219/1219 ━━━━━━━━━━━━━━━━━━━━ 42s 29ms/step - loss: 2.3640e-04 - val_loss: 3.2049e-04 - learning_rate: 1.0000e-04
# Epoch 12/50
# 1219/1219 ━━━━━━━━━━━━━━━━━━━━ 41s 29ms/step - loss: 2.2677e-04 - val_loss: 3.4560e-04 - learning_rate: 1.0000e-04
# Epoch 13/50
# 1219/1219 ━━━━━━━━━━━━━━━━━━━━ 41s 29ms/step - loss: 2.4338e-04 - val_loss: 3.0419e-04 - learning_rate: 1.0000e-05
# Epoch 14/50
# 1219/1219 ━━━━━━━━━━━━━━━━━━━━ 41s 29ms/step - loss: 2.3075e-04 - val_loss: 3.0237e-04 - learning_rate: 1.0000e-05
# Epoch 15/50
# 1219/1219 ━━━━━━━━━━━━━━━━━━━━ 41s 29ms/step - loss: 2.4204e-04 - val_loss: 3.0948e-04 - learning_rate: 1.0000e-05
# Epoch 16/50
# 1219/1219 ━━━━━━━━━━━━━━━━━━━━ 41s 29ms/step - loss: 2.4380e-04 - val_loss: 3.0488e-04 - learning_rate: 1.0000e-06
# Epoch 17/50
# 1219/1219 ━━━━━━━━━━━━━━━━━━━━ 35s 29ms/step - loss: 2.3111e-04 - val_loss: 3.0408e-04 - learning_rate: 1.0000e-06
# Epoch 18/50
# 1219/1219 ━━━━━━━━━━━━━━━━━━━━ 35s 29ms/step - loss: 2.1896e-04 - val_loss: 3.0386e-04 - learning_rate: 1.0000e-06
# Epoch 19/50
# 1219/1219 ━━━━━━━━━━━━━━━━━━━━ 41s 29ms/step - loss: 2.2856e-04 - val_loss: 3.0348e-04 - learning_rate: 1.0000e-07
# Epoch 20/50
# 1219/1219 ━━━━━━━━━━━━━━━━━━━━ 41s 29ms/step - loss: 2.2631e-04 - val_loss: 3.0346e-04 - learning_rate: 1.0000e-07
# Epoch 21/50
# 1219/1219 ━━━━━━━━━━━━━━━━━━━━ 41s 29ms/step - loss: 2.3753e-04 - val_loss: 3.0331e-04 - learning_rate: 1.0000e-07
# Validierungsverlust: 0.000302

# %%
# Modell erstellen
model_RNN_DO = Sequential()
model_RNN_DO.add(SimpleRNN(units=64,
                input_shape=(X_tr.shape[1], X_tr.shape[2]),
                dropout = 0.2,
                return_sequences=True))
model_RNN_DO.add(SimpleRNN(units=64, dropout = 0.2, return_sequences=True))
model_RNN_DO.add(SimpleRNN(units=64, dropout = 0.2,))
model_RNN_DO.add(Dense(1, activation='linear'))

# Modell kompilieren
model_RNN_DO.compile(optimizer=Adam(learning_rate=0.01),
              loss='mean_squared_error')

# EarlyStopping Callback definieren
early_stop = EarlyStopping(monitor='val_loss', patience=7, restore_best_weights=True)

# Lernratenabbaufaktor
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=3, min_lr=1e-8)

# Training durchführen
history = model_RNN_DO.fit(X_tr, y_tr, epochs=50, batch_size=64,
                    validation_data=(X_v, y_v), callbacks=[early_stop, reduce_lr])

# Validation Loss speichern
val_loss = np.min(history.history['val_loss'])
print(f"Validierungsverlust: {val_loss:.6f}")
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/50
# 1219/1219 ━━━━━━━━━━━━━━━━━━━━ 44s 33ms/step - loss: 0.0402 - val_loss: 9.1742e-04 - learning_rate: 0.0100
# Epoch 2/50
# 1219/1219 ━━━━━━━━━━━━━━━━━━━━ 39s 32ms/step - loss: 6.4110e-04 - val_loss: 5.1309e-04 - learning_rate: 0.0100
# Epoch 3/50
# 1219/1219 ━━━━━━━━━━━━━━━━━━━━ 41s 32ms/step - loss: 7.9633e-04 - val_loss: 6.1689e-04 - learning_rate: 0.0100
# Epoch 4/50
# 1219/1219 ━━━━━━━━━━━━━━━━━━━━ 41s 32ms/step - loss: 7.1860e-04 - val_loss: 4.9552e-04 - learning_rate: 0.0100
# Epoch 5/50
# 1219/1219 ━━━━━━━━━━━━━━━━━━━━ 39s 32ms/step - loss: 7.1879e-04 - val_loss: 0.0016 - learning_rate: 0.0100
# Epoch 6/50
# 1219/1219 ━━━━━━━━━━━━━━━━━━━━ 41s 32ms/step - loss: 4.3245e-04 - val_loss: 4.9134e-04 - learning_rate: 1.0000e-03
# Epoch 7/50
# 1219/1219 ━━━━━━━━━━━━━━━━━━━━ 41s 32ms/step - loss: 4.1462e-04 - val_loss: 5.9603e-04 - learning_rate: 1.0000e-03
# Epoch 8/50
# 1219/1219 ━━━━━━━━━━━━━━━━━━━━ 41s 31ms/step - loss: 4.1349e-04 - val_loss: 4.8670e-04 - learning_rate: 1.0000e-03
# Epoch 9/50
# 1219/1219 ━━━━━━━━━━━━━━━━━━━━ 42s 32ms/step - loss: 3.7702e-04 - val_loss: 4.8895e-04 - learning_rate: 1.0000e-04
# Epoch 10/50
# 1219/1219 ━━━━━━━━━━━━━━━━━━━━ 41s 32ms/step - loss: 3.9528e-04 - val_loss: 4.8332e-04 - learning_rate: 1.0000e-04
# Epoch 11/50
# 1219/1219 ━━━━━━━━━━━━━━━━━━━━ 41s 32ms/step - loss: 3.9921e-04 - val_loss: 4.9918e-04 - learning_rate: 1.0000e-04
# Epoch 12/50
# 1219/1219 ━━━━━━━━━━━━━━━━━━━━ 41s 32ms/step - loss: 3.8722e-04 - val_loss: 4.8954e-04 - learning_rate: 1.0000e-05
# Epoch 13/50
# 1219/1219 ━━━━━━━━━━━━━━━━━━━━ 42s 32ms/step - loss: 3.8193e-04 - val_loss: 4.8228e-04 - learning_rate: 1.0000e-05
# Epoch 14/50
# 1219/1219 ━━━━━━━━━━━━━━━━━━━━ 40s 32ms/step - loss: 3.8729e-04 - val_loss: 4.8418e-04 - learning_rate: 1.0000e-05
# Epoch 15/50
# 1219/1219 ━━━━━━━━━━━━━━━━━━━━ 40s 31ms/step - loss: 3.9140e-04 - val_loss: 4.8301e-04 - learning_rate: 1.0000e-06
# Epoch 16/50
# 1219/1219 ━━━━━━━━━━━━━━━━━━━━ 42s 32ms/step - loss: 3.7936e-04 - val_loss: 4.8329e-04 - learning_rate: 1.0000e-06
# Epoch 17/50
# 1219/1219 ━━━━━━━━━━━━━━━━━━━━ 41s 32ms/step - loss: 3.9232e-04 - val_loss: 4.8365e-04 - learning_rate: 1.0000e-06
# Epoch 18/50
# 1219/1219 ━━━━━━━━━━━━━━━━━━━━ 39s 32ms/step - loss: 3.9700e-04 - val_loss: 4.8324e-04 - learning_rate: 1.0000e-07
# Epoch 19/50
# 1219/1219 ━━━━━━━━━━━━━━━━━━━━ 42s 33ms/step - loss: 3.8715e-04 - val_loss: 4.8283e-04 - learning_rate: 1.0000e-07
# Epoch 20/50
# 1219/1219 ━━━━━━━━━━━━━━━━━━━━ 41s 33ms/step - loss: 3.7702e-04 - val_loss: 4.8299e-04 - learning_rate: 1.0000e-07
# Validierungsverlust: 0.000482

# %%
# Modell erstellen
model_RNN_ReLU = Sequential()
model_RNN_ReLU.add(SimpleRNN(units=64,
                input_shape=(X_tr.shape[1], X_tr.shape[2]),
                activation='relu', return_sequences=True))
model_RNN_ReLU.add(SimpleRNN(units=64, activation='relu', return_sequences=True))
model_RNN_ReLU.add(SimpleRNN(units=64, activation='relu'))
model_RNN_ReLU.add(Dense(1, activation='linear'))

# Modell kompilieren
model_RNN_ReLU.compile(optimizer=Adam(learning_rate=0.01),
              loss='mean_squared_error')

# EarlyStopping Callback definieren
early_stop = EarlyStopping(monitor='val_loss', patience=7, restore_best_weights=True)

# Lernratenabbaufaktor
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=3, min_lr=1e-8)

# Training durchführen
history = model_RNN_ReLU.fit(X_tr, y_tr, epochs=50, batch_size=64,
                    validation_data=(X_v, y_v), callbacks=[early_stop, reduce_lr])

# Validation Loss speichern
val_loss = np.min(history.history['val_loss'])
print(f"Validierungsverlust: {val_loss:.6f}")
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/50
# 1219/1219 ━━━━━━━━━━━━━━━━━━━━ 40s 28ms/step - loss: 1.4508 - val_loss: 6.2520e-04 - learning_rate: 0.0100
# Epoch 2/50
# 1219/1219 ━━━━━━━━━━━━━━━━━━━━ 41s 27ms/step - loss: 6.6656e-04 - val_loss: 6.9469e-04 - learning_rate: 0.0100
# Epoch 3/50
# 1219/1219 ━━━━━━━━━━━━━━━━━━━━ 41s 28ms/step - loss: 4.6083e-04 - val_loss: 4.5583e-04 - learning_rate: 0.0100
# Epoch 4/50
# 1219/1219 ━━━━━━━━━━━━━━━━━━━━ 35s 29ms/step - loss: 3.9730e-04 - val_loss: 4.4544e-04 - learning_rate: 0.0100
# Epoch 5/50
# 1219/1219 ━━━━━━━━━━━━━━━━━━━━ 39s 27ms/step - loss: 3.6814e-04 - val_loss: 4.1290e-04 - learning_rate: 0.0100
# Epoch 6/50
# 1219/1219 ━━━━━━━━━━━━━━━━━━━━ 35s 28ms/step - loss: 3.7475e-04 - val_loss: 6.0142e-04 - learning_rate: 0.0100
# Epoch 7/50
# 1219/1219 ━━━━━━━━━━━━━━━━━━━━ 43s 30ms/step - loss: 2.8888e-04 - val_loss: 3.5421e-04 - learning_rate: 1.0000e-03
# Epoch 8/50
# 1219/1219 ━━━━━━━━━━━━━━━━━━━━ 39s 28ms/step - loss: 2.5282e-04 - val_loss: 3.3915e-04 - learning_rate: 1.0000e-03
# Epoch 9/50
# 1219/1219 ━━━━━━━━━━━━━━━━━━━━ 41s 28ms/step - loss: 2.5115e-04 - val_loss: 3.3551e-04 - learning_rate: 1.0000e-03
# Epoch 10/50
# 1219/1219 ━━━━━━━━━━━━━━━━━━━━ 40s 27ms/step - loss: 2.7760e-04 - val_loss: 3.5032e-04 - learning_rate: 1.0000e-03
# Epoch 11/50
# 1219/1219 ━━━━━━━━━━━━━━━━━━━━ 46s 31ms/step - loss: 2.3155e-04 - val_loss: 3.0465e-04 - learning_rate: 1.0000e-04
# Epoch 12/50
# 1219/1219 ━━━━━━━━━━━━━━━━━━━━ 37s 28ms/step - loss: 2.3494e-04 - val_loss: 2.9727e-04 - learning_rate: 1.0000e-04
# Epoch 13/50
# 1219/1219 ━━━━━━━━━━━━━━━━━━━━ 40s 28ms/step - loss: 2.2611e-04 - val_loss: 3.0252e-04 - learning_rate: 1.0000e-04
# Epoch 14/50
# 1219/1219 ━━━━━━━━━━━━━━━━━━━━ 40s 27ms/step - loss: 2.2275e-04 - val_loss: 2.9835e-04 - learning_rate: 1.0000e-05
# Epoch 15/50
# 1219/1219 ━━━━━━━━━━━━━━━━━━━━ 41s 28ms/step - loss: 2.2662e-04 - val_loss: 2.9543e-04 - learning_rate: 1.0000e-05
# Epoch 16/50
# 1219/1219 ━━━━━━━━━━━━━━━━━━━━ 35s 29ms/step - loss: 2.2232e-04 - val_loss: 2.9942e-04 - learning_rate: 1.0000e-05
# Epoch 17/50
# 1219/1219 ━━━━━━━━━━━━━━━━━━━━ 33s 27ms/step - loss: 2.2857e-04 - val_loss: 2.9611e-04 - learning_rate: 1.0000e-06
# Epoch 18/50
# 1219/1219 ━━━━━━━━━━━━━━━━━━━━ 41s 27ms/step - loss: 2.2459e-04 - val_loss: 2.9779e-04 - learning_rate: 1.0000e-06
# Epoch 19/50
# 1219/1219 ━━━━━━━━━━━━━━━━━━━━ 33s 27ms/step - loss: 2.1991e-04 - val_loss: 2.9749e-04 - learning_rate: 1.0000e-06
# Epoch 20/50
# 1219/1219 ━━━━━━━━━━━━━━━━━━━━ 34s 28ms/step - loss: 2.2486e-04 - val_loss: 2.9718e-04 - learning_rate: 1.0000e-07
# Epoch 21/50
# 1219/1219 ━━━━━━━━━━━━━━━━━━━━ 33s 27ms/step - loss: 2.1933e-04 - val_loss: 2.9712e-04 - learning_rate: 1.0000e-07
# Epoch 22/50
# 1219/1219 ━━━━━━━━━━━━━━━━━━━━ 36s 30ms/step - loss: 2.2101e-04 - val_loss: 2.9701e-04 - learning_rate: 1.0000e-07
# Validierungsverlust: 0.000295

# %%
# Modell erstellen
model_RNN_ReLU_5 = Sequential()
model_RNN_ReLU_5.add(SimpleRNN(units=64,
                input_shape=(X_tr.shape[1], X_tr.shape[2]),
                activation='relu', return_sequences=True))
model_RNN_ReLU_5.add(SimpleRNN(units=64, activation='relu', return_sequences=True))
model_RNN_ReLU_5.add(SimpleRNN(units=64, activation='relu'))
model_RNN_ReLU_5.add(Dense(1, activation='linear'))

# Modell kompilieren
model_RNN_ReLU_5.compile(optimizer=Adam(learning_rate=0.01),
              loss='mean_squared_error')

# EarlyStopping Callback definieren
early_stop = EarlyStopping(monitor='val_loss', patience=7, restore_best_weights=True)

# Lernratenabbaufaktor
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3, min_lr=1e-8)

# Training durchführen
history = model_RNN_ReLU_5.fit(X_tr, y_tr, epochs=50, batch_size=64,
                    validation_data=(X_v, y_v), callbacks=[early_stop, reduce_lr])

# Validation Loss speichern
val_loss = np.min(history.history['val_loss'])
print(f"Validierungsverlust: {val_loss:.6f}")
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/50
# 1219/1219 ━━━━━━━━━━━━━━━━━━━━ 41s 29ms/step - loss: 4.2112 - val_loss: 5.3155e-04 - learning_rate: 0.0100
# Epoch 2/50
# 1219/1219 ━━━━━━━━━━━━━━━━━━━━ 40s 29ms/step - loss: 5.4640e-04 - val_loss: 8.3439e-04 - learning_rate: 0.0100
# Epoch 3/50
# 1219/1219 ━━━━━━━━━━━━━━━━━━━━ 37s 31ms/step - loss: 9.2033e-04 - val_loss: 0.0048 - learning_rate: 0.0100
# Epoch 4/50
# 1219/1219 ━━━━━━━━━━━━━━━━━━━━ 41s 30ms/step - loss: 7.2126e-04 - val_loss: 0.0017 - learning_rate: 0.0100
# Epoch 5/50
# 1219/1219 ━━━━━━━━━━━━━━━━━━━━ 39s 29ms/step - loss: 4.3179e-04 - val_loss: 4.4606e-04 - learning_rate: 0.0050
# Epoch 6/50
# 1219/1219 ━━━━━━━━━━━━━━━━━━━━ 40s 28ms/step - loss: 3.8442e-04 - val_loss: 4.5563e-04 - learning_rate: 0.0050
# Epoch 7/50
# 1219/1219 ━━━━━━━━━━━━━━━━━━━━ 37s 30ms/step - loss: 4.3920e-04 - val_loss: 4.8842e-04 - learning_rate: 0.0050
# Epoch 8/50
# 1219/1219 ━━━━━━━━━━━━━━━━━━━━ 45s 33ms/step - loss: 3.3567e-04 - val_loss: 3.6658e-04 - learning_rate: 0.0025
# Epoch 9/50
# 1219/1219 ━━━━━━━━━━━━━━━━━━━━ 36s 29ms/step - loss: 3.0770e-04 - val_loss: 4.2450e-04 - learning_rate: 0.0025
# Epoch 10/50
# 1219/1219 ━━━━━━━━━━━━━━━━━━━━ 41s 29ms/step - loss: 2.9373e-04 - val_loss: 4.8671e-04 - learning_rate: 0.0025
# Epoch 11/50
# 1219/1219 ━━━━━━━━━━━━━━━━━━━━ 41s 29ms/step - loss: 2.9017e-04 - val_loss: 4.3961e-04 - learning_rate: 0.0025
# Epoch 12/50
# 1219/1219 ━━━━━━━━━━━━━━━━━━━━ 41s 29ms/step - loss: 2.7536e-04 - val_loss: 3.5554e-04 - learning_rate: 0.0012
# Epoch 13/50
# 1219/1219 ━━━━━━━━━━━━━━━━━━━━ 37s 30ms/step - loss: 2.6553e-04 - val_loss: 3.5340e-04 - learning_rate: 0.0012
# Epoch 14/50
# 1219/1219 ━━━━━━━━━━━━━━━━━━━━ 35s 29ms/step - loss: 3.0833e-04 - val_loss: 3.6580e-04 - learning_rate: 0.0012
# Epoch 15/50
# 1219/1219 ━━━━━━━━━━━━━━━━━━━━ 41s 29ms/step - loss: 2.3318e-04 - val_loss: 3.9727e-04 - learning_rate: 6.2500e-04
# Epoch 16/50
# 1219/1219 ━━━━━━━━━━━━━━━━━━━━ 41s 29ms/step - loss: 2.4718e-04 - val_loss: 3.7313e-04 - learning_rate: 6.2500e-04
# Epoch 17/50
# 1219/1219 ━━━━━━━━━━━━━━━━━━━━ 40s 29ms/step - loss: 2.1279e-04 - val_loss: 3.2378e-04 - learning_rate: 6.2500e-04
# Epoch 18/50
# 1219/1219 ━━━━━━━━━━━━━━━━━━━━ 37s 30ms/step - loss: 2.3185e-04 - val_loss: 3.2717e-04 - learning_rate: 3.1250e-04
# Epoch 19/50
# 1219/1219 ━━━━━━━━━━━━━━━━━━━━ 40s 29ms/step - loss: 2.1821e-04 - val_loss: 3.2887e-04 - learning_rate: 3.1250e-04
# Epoch 20/50
# 1219/1219 ━━━━━━━━━━━━━━━━━━━━ 40s 29ms/step - loss: 2.1444e-04 - val_loss: 3.4357e-04 - learning_rate: 3.1250e-04
# Epoch 21/50
# 1219/1219 ━━━━━━━━━━━━━━━━━━━━ 41s 29ms/step - loss: 2.1609e-04 - val_loss: 3.2980e-04 - learning_rate: 1.5625e-04
# Epoch 22/50
# 1219/1219 ━━━━━━━━━━━━━━━━━━━━ 37s 31ms/step - loss: 2.0481e-04 - val_loss: 3.2530e-04 - learning_rate: 1.5625e-04
# Epoch 23/50
# 1219/1219 ━━━━━━━━━━━━━━━━━━━━ 41s 31ms/step - loss: 2.0605e-04 - val_loss: 3.1779e-04 - learning_rate: 1.5625e-04
# Epoch 24/50
# 1219/1219 ━━━━━━━━━━━━━━━━━━━━ 40s 30ms/step - loss: 1.9807e-04 - val_loss: 3.2243e-04 - learning_rate: 7.8125e-05
# Epoch 25/50
# 1219/1219 ━━━━━━━━━━━━━━━━━━━━ 41s 30ms/step - loss: 1.9418e-04 - val_loss: 3.3191e-04 - learning_rate: 7.8125e-05
# Epoch 26/50
# 1219/1219 ━━━━━━━━━━━━━━━━━━━━ 41s 30ms/step - loss: 1.9152e-04 - val_loss: 3.2430e-04 - learning_rate: 7.8125e-05
# Epoch 27/50
# 1219/1219 ━━━━━━━━━━━━━━━━━━━━ 42s 31ms/step - loss: 1.9520e-04 - val_loss: 3.1758e-04 - learning_rate: 3.9062e-05
# Epoch 28/50
# 1219/1219 ━━━━━━━━━━━━━━━━━━━━ 41s 31ms/step - loss: 2.0233e-04 - val_loss: 3.2595e-04 - learning_rate: 3.9062e-05
# Epoch 29/50
# 1219/1219 ━━━━━━━━━━━━━━━━━━━━ 40s 30ms/step - loss: 1.9548e-04 - val_loss: 3.1287e-04 - learning_rate: 3.9062e-05
# Epoch 30/50
# 1219/1219 ━━━━━━━━━━━━━━━━━━━━ 39s 32ms/step - loss: 1.9064e-04 - val_loss: 3.1671e-04 - learning_rate: 1.9531e-05
# Epoch 31/50
# 1219/1219 ━━━━━━━━━━━━━━━━━━━━ 41s 32ms/step - loss: 1.9167e-04 - val_loss: 3.2058e-04 - learning_rate: 1.9531e-05
# Epoch 32/50
# 1219/1219 ━━━━━━━━━━━━━━━━━━━━ 39s 31ms/step - loss: 1.9689e-04 - val_loss: 3.1505e-04 - learning_rate: 1.9531e-05
# Epoch 33/50
# 1219/1219 ━━━━━━━━━━━━━━━━━━━━ 41s 31ms/step - loss: 1.9331e-04 - val_loss: 3.1633e-04 - learning_rate: 9.7656e-06
# Epoch 34/50
# 1219/1219 ━━━━━━━━━━━━━━━━━━━━ 40s 30ms/step - loss: 2.0734e-04 - val_loss: 3.1362e-04 - learning_rate: 9.7656e-06
# Epoch 35/50
# 1219/1219 ━━━━━━━━━━━━━━━━━━━━ 39s 32ms/step - loss: 1.8717e-04 - val_loss: 3.1483e-04 - learning_rate: 9.7656e-06
# Epoch 36/50
# 1219/1219 ━━━━━━━━━━━━━━━━━━━━ 38s 31ms/step - loss: 1.8725e-04 - val_loss: 3.1427e-04 - learning_rate: 4.8828e-06
# Validierungsverlust: 0.000313
